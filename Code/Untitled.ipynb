# %%
import pandas as pd
import numpy as np

# %%
raw_data = pd.read_csv('../Data/NYC_Rest_Inspect.csv')

# %%
raw_data['INSPECTION DATE'] = pd.to_datetime(raw_data['INSPECTION DATE'], format = '%m/%d/%Y')
raw_data['GRADE DATE'] = pd.to_datetime(raw_data['GRADE DATE'], format = '%m/%d/%Y')
raw_data['RECORD DATE'] = pd.to_datetime(raw_data['RECORD DATE'], format = '%m/%d/%Y')

# %%
raw_data['BORO'].unique()
# Out:
# array(['QUEENS', 'BROOKLYN', 'MANHATTAN', 'STATEN ISLAND', 'BRONX',
#        'Missing'], dtype=object)

# %%
raw_data[ raw_data]
# Out:
# array(['Spanish', 'Japanese', 'Bakery', 'Pizza/Italian',
#        'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#        'American', 'Peruvian', 'Mediterranean', 'Turkish', 'Other',
#        'Italian', 'Chinese', 'Pizza', 'Caribbean', 'Indian',
#        'CafÃ©/Coffee/Tea', 'Barbecue', 'Soul Food', 'Jewish/Kosher',
#        'Delicatessen', 'Seafood', 'Mexican', 'Irish', 'Chicken', 'French',
#        'Juice, Smoothies, Fruit Salads', 'Vietnamese/Cambodian/Malaysia',
#        'Hamburgers', 'Donuts', 'Tex-Mex', 'Asian', 'Korean', 'Salads',
#        'Ice Cream, Gelato, Yogurt, Ices', 'Bagels/Pretzels', 'Pakistani',
#        'Sandwiches/Salads/Mixed Buffet',
#        'Bottled beverages, including water, sodas, juices, etc.',
#        'Brazilian', 'Steak', 'Continental', 'Chinese/Japanese',
#        'Middle Eastern', 'Filipino', 'Thai', 'African',
#        'Eastern European', 'Vegetarian', 'Creole', 'Scandinavian',
#        'Sandwiches', 'Soups & Sandwiches', 'Hotdogs/Pretzels',
#        'Bangladeshi', 'Australian', 'Egyptian', 'Iranian', 'Armenian',
#        'Moroccan', 'Russian', 'Portuguese', 'Greek', 'English',
#        'Southwestern', 'Fruits/Vegetables', 'Chinese/Cuban', 'Hawaiian',
#        'Hotdogs', 'Polish', 'German', 'Cajun', 'Ethiopian', 'Chilean',
#        'Creole/Cajun', 'Tapas', 'Soups', 'Pancakes/Waffles',
#        'Californian', 'Not Listed/Not Applicable', 'Afghan', 'Indonesian',
#        'Czech', 'Nuts/Confectionary', 'Polynesian', 'Basque'],
#       dtype=object)

# %%
data = raw_data[ (raw_data["BORO"] == "MANHATTAN") & (raw_data["CUISINE DESCRIPTION"] == "American") ]

# %%
index = (data.groupby(['DBA'])['INSPECTION DATE'].nlargest(1))

# %%
data['DBA'].unique().shape
# Out:
# (2724,)

# %%
data[ data['DBA'] == 'THE ELK']
# Out:
#            CAMIS      DBA       BORO BUILDING      STREET  ZIPCODE  \
# 6       50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 8124    50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 9609    50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 12961   50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 14899   50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 26474   50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 57005   50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 86586   50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 89862   50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 92828   50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 124341  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 125325  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 132519  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 169961  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 179807  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 198718  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 215308  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 216011  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 228036  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 236345  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 237786  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 259425  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 281977  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 308358  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 309555  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 315127  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 327557  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 335923  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 352564  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 364474  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
# 374179  50008995  THE ELK  MANHATTAN      128  CHARLES ST  10014.0
#
#              PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 6       2129334780            American      2018-04-02
# 8124    2129334780            American      2016-12-21
# 9609    2129334780            American      2017-10-30
# 12961   2129334780            American      2018-09-05
# 14899   2129334780            American      2018-04-25
# 26474   2129334780            American      2017-10-30
# 57005   2129334780            American      2017-08-29
# 86586   2129334780            American      2018-09-26
# 89862   2129334780            American      2016-12-02
# 92828   2129334780            American      2018-09-26
# 124341  2129334780            American      2016-12-02
# 125325  2129334780            American      2017-10-30
# 132519  2129334780            American      2018-04-25
# 169961  2129334780            American      2018-04-02
# 179807  2129334780            American      2016-12-21
# 198718  2129334780            American      2017-08-29
# 215308  2129334780            American      2016-12-02
# 216011  2129334780            American      2015-11-24
# 228036  2129334780            American      2017-08-29
# 236345  2129334780            American      2018-09-05
# 237786  2129334780            American      2015-11-24
# 259425  2129334780            American      2017-08-29
# 281977  2129334780            American      2018-04-02
# 308358  2129334780            American      2018-04-02
# 309555  2129334780            American      2018-09-05
# 315127  2129334780            American      2016-12-21
# 327557  2129334780            American      2015-11-24
# 335923  2129334780            American      2018-04-02
# 352564  2129334780            American      2018-09-05
# 364474  2129334780            American      2016-12-02
# 374179  2129334780            American      2017-08-29
#
#                                                  ACTION VIOLATION CODE  \
# 6       Violations were cited in the following area(s).            06D
# 8124    Violations were cited in the following area(s).            10F
# 9609    Violations were cited in the following area(s).            10B
# 12961   Violations were cited in the following area(s).            10I
# 14899   Violations were cited in the following area(s).            04H
# 26474   Violations were cited in the following area(s).            02G
# 57005   Violations were cited in the following area(s).            04H
# 86586   Violations were cited in the following area(s).            04O
# 89862   Violations were cited in the following area(s).            10F
# 92828   Violations were cited in the following area(s).            10B
# 124341  Violations were cited in the following area(s).            02G
# 125325  Violations were cited in the following area(s).            10F
# 132519  Violations were cited in the following area(s).            10B
# 169961  Violations were cited in the following area(s).            06A
# 179807  Violations were cited in the following area(s).            10B
# 198718  Violations were cited in the following area(s).            08A
# 215308  Violations were cited in the following area(s).            06D
# 216011  Violations were cited in the following area(s).            10F
# 228036  Violations were cited in the following area(s).            10F
# 236345  Violations were cited in the following area(s).            10B
# 237786  Violations were cited in the following area(s).            08A
# 259425  Violations were cited in the following area(s).            04L
# 281977  Violations were cited in the following area(s).            08A
# 308358  Violations were cited in the following area(s).            04L
# 309555  Violations were cited in the following area(s).            08A
# 315127  Violations were cited in the following area(s).            06D
# 327557  Violations were cited in the following area(s).            04N
# 335923  Violations were cited in the following area(s).            04A
# 352564  Violations were cited in the following area(s).            04N
# 364474  Violations were cited in the following area(s).            06C
# 374179  Violations were cited in the following area(s).            04N
#
#                                     VIOLATION DESCRIPTION CRITICAL FLAG  \
# 6       Food contact surface not properly washed, rins...      Critical
# 8124    Non-food contact surface improperly constructe...  Not Critical
# 9609    Plumbing not properly installed or maintained;...  Not Critical
# 12961   Single service item reused, improperly stored,...  Not Critical
# 14899   Raw, cooked or prepared food is adulterated, c...      Critical
# 26474   Cold food item held above 41Âº F (smoked fish ...      Critical
# 57005   Raw, cooked or prepared food is adulterated, c...      Critical
# 86586   Live animals other than fish in tank or servic...      Critical
# 89862   Non-food contact surface improperly constructe...  Not Critical
# 92828   Plumbing not properly installed or maintained;...  Not Critical
# 124341  Cold food item held above 41Âº F (smoked fish ...      Critical
# 125325  Non-food contact surface improperly constructe...  Not Critical
# 132519  Plumbing not properly installed or maintained;...  Not Critical
# 169961  Personal cleanliness inadequate. Outer garment...      Critical
# 179807  Plumbing not properly installed or maintained;...  Not Critical
# 198718  Facility not vermin proof. Harborage or condit...  Not Critical
# 215308  Food contact surface not properly washed, rins...      Critical
# 216011  Non-food contact surface improperly constructe...  Not Critical
# 228036  Non-food contact surface improperly constructe...  Not Critical
# 236345  Plumbing not properly installed or maintained;...  Not Critical
# 237786  Facility not vermin proof. Harborage or condit...  Not Critical
# 259425  Evidence of mice or live mice present in facil...      Critical
# 281977  Facility not vermin proof. Harborage or condit...  Not Critical
# 308358  Evidence of mice or live mice present in facil...      Critical
# 309555  Facility not vermin proof. Harborage or condit...  Not Critical
# 315127  Food contact surface not properly washed, rins...      Critical
# 327557  Filth flies or food/refuse/sewage-associated (...      Critical
# 335923  Food Protection Certificate not held by superv...      Critical
# 352564  Filth flies or food/refuse/sewage-associated (...      Critical
# 364474  Food not protected from potential source of co...      Critical
# 374179  Filth flies or food/refuse/sewage-associated (...      Critical
#
#         SCORE GRADE GRADE DATE RECORD DATE  \
# 6        31.0   NaN        NaT  2018-11-12
# 8124      9.0     A 2016-12-21  2018-11-12
# 9609     11.0     A 2017-10-30  2018-11-12
# 12961    16.0   NaN        NaT  2018-11-12
# 14899    10.0     A 2018-04-25  2018-11-12
# 26474    11.0     A 2017-10-30  2018-11-12
# 57005    19.0   NaN        NaT  2018-11-12
# 86586     7.0     A 2018-09-26  2018-11-12
# 89862    23.0   NaN        NaT  2018-11-12
# 92828     7.0     A 2018-09-26  2018-11-12
# 124341   23.0   NaN        NaT  2018-11-12
# 125325   11.0     A 2017-10-30  2018-11-12
# 132519   10.0     A 2018-04-25  2018-11-12
# 169961   31.0   NaN        NaT  2018-11-12
# 179807    9.0     A 2016-12-21  2018-11-12
# 198718   19.0   NaN        NaT  2018-11-12
# 215308   23.0   NaN        NaT  2018-11-12
# 216011   12.0     A 2015-11-24  2018-11-12
# 228036   19.0   NaN        NaT  2018-11-12
# 236345   16.0   NaN        NaT  2018-11-12
# 237786   12.0     A 2015-11-24  2018-11-12
# 259425   19.0   NaN        NaT  2018-11-12
# 281977   31.0   NaN        NaT  2018-11-12
# 308358   31.0   NaN        NaT  2018-11-12
# 309555   16.0   NaN        NaT  2018-11-12
# 315127    9.0     A 2016-12-21  2018-11-12
# 327557   12.0     A 2015-11-24  2018-11-12
# 335923   31.0   NaN        NaT  2018-11-12
# 352564   16.0   NaN        NaT  2018-11-12
# 364474   23.0   NaN        NaT  2018-11-12
# 374179   19.0   NaN        NaT  2018-11-12
#
#                               INSPECTION TYPE
# 6       Cycle Inspection / Initial Inspection
# 8124         Cycle Inspection / Re-inspection
# 9609         Cycle Inspection / Re-inspection
# 12961   Cycle Inspection / Initial Inspection
# 14899        Cycle Inspection / Re-inspection
# 26474        Cycle Inspection / Re-inspection
# 57005   Cycle Inspection / Initial Inspection
# 86586        Cycle Inspection / Re-inspection
# 89862   Cycle Inspection / Initial Inspection
# 92828        Cycle Inspection / Re-inspection
# 124341  Cycle Inspection / Initial Inspection
# 125325       Cycle Inspection / Re-inspection
# 132519       Cycle Inspection / Re-inspection
# 169961  Cycle Inspection / Initial Inspection
# 179807       Cycle Inspection / Re-inspection
# 198718  Cycle Inspection / Initial Inspection
# 215308  Cycle Inspection / Initial Inspection
# 216011  Cycle Inspection / Initial Inspection
# 228036  Cycle Inspection / Initial Inspection
# 236345  Cycle Inspection / Initial Inspection
# 237786  Cycle Inspection / Initial Inspection
# 259425  Cycle Inspection / Initial Inspection
# 281977  Cycle Inspection / Initial Inspection
# 308358  Cycle Inspection / Initial Inspection
# 309555  Cycle Inspection / Initial Inspection
# 315127       Cycle Inspection / Re-inspection
# 327557  Cycle Inspection / Initial Inspection
# 335923  Cycle Inspection / Initial Inspection
# 352564  Cycle Inspection / Initial Inspection
# 364474  Cycle Inspection / Initial Inspection
# 374179  Cycle Inspection / Initial Inspection

# %%
data.groupby(['DBA']).get_group('FUEL GRILL AND JUICE BAR').sort_values(by = 'INSPECTION DATE')
# Out:
#            CAMIS                       DBA       BORO BUILDING   STREET  \
# 377658  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 297065  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 341600  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 193004  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 12      50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 14685   50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 128658  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 74945   50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 65739   50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 255252  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 270277  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 283577  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 326819  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 327638  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 176638  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 208115  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
# 240330  50071738  FUEL GRILL AND JUICE BAR  MANHATTAN      683  9TH AVE
#
#         ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 377658  10036.0  2126494664            American      2018-01-23
# 297065  10036.0  2126494664            American      2018-01-23
# 341600  10036.0  2126494664            American      2018-01-23
# 193004  10036.0  2126494664            American      2018-01-23
# 12      10036.0  2126494664            American      2018-03-07
# 14685   10036.0  2126494664            American      2018-03-07
# 128658  10036.0  2126494664            American      2018-03-07
# 74945   10036.0  2126494664            American      2018-10-01
# 65739   10036.0  2126494664            American      2018-10-01
# 255252  10036.0  2126494664            American      2018-10-01
# 270277  10036.0  2126494664            American      2018-10-01
# 283577  10036.0  2126494664            American      2018-10-01
# 326819  10036.0  2126494664            American      2018-10-01
# 327638  10036.0  2126494664            American      2018-10-01
# 176638  10036.0  2126494664            American      2018-10-09
# 208115  10036.0  2126494664            American      2018-10-09
# 240330  10036.0  2126494664            American      2018-10-09
#
#                                                  ACTION VIOLATION CODE  \
# 377658  Violations were cited in the following area(s).            08A
# 297065  Violations were cited in the following area(s).            10F
# 341600  Violations were cited in the following area(s).            04L
# 193004  Violations were cited in the following area(s).            02B
# 12      Violations were cited in the following area(s).            04L
# 14685   Violations were cited in the following area(s).            08A
# 128658  Violations were cited in the following area(s).            10F
# 74945   Violations were cited in the following area(s).            04N
# 65739   Violations were cited in the following area(s).            06C
# 255252  Violations were cited in the following area(s).            04L
# 270277  Violations were cited in the following area(s).            02G
# 283577  Violations were cited in the following area(s).            08A
# 326819  Violations were cited in the following area(s).            10I
# 327638  Violations were cited in the following area(s).            18D
# 176638  Violations were cited in the following area(s).            08A
# 208115  Violations were cited in the following area(s).            04N
# 240330  Violations were cited in the following area(s).            09C
#
#                                     VIOLATION DESCRIPTION CRITICAL FLAG  \
# 377658  Facility not vermin proof. Harborage or condit...  Not Critical
# 297065  Non-food contact surface improperly constructe...  Not Critical
# 341600  Evidence of mice or live mice present in facil...      Critical
# 193004        Hot food item not held at or above 140Âº F.      Critical
# 12      Evidence of mice or live mice present in facil...      Critical
# 14685   Facility not vermin proof. Harborage or condit...  Not Critical
# 128658  Non-food contact surface improperly constructe...  Not Critical
# 74945   Filth flies or food/refuse/sewage-associated (...      Critical
# 65739   Food not protected from potential source of co...      Critical
# 255252  Evidence of mice or live mice present in facil...      Critical
# 270277  Cold food item held above 41Âº F (smoked fish ...      Critical
# 283577  Facility not vermin proof. Harborage or condit...  Not Critical
# 326819  Single service item reused, improperly stored,...  Not Critical
# 327638  Failure to comply with an Order of the Board o...  Not Critical
# 176638  Facility not vermin proof. Harborage or condit...  Not Critical
# 208115  Filth flies or food/refuse/sewage-associated (...      Critical
# 240330      Food contact surface not properly maintained.  Not Critical
#
#         SCORE GRADE GRADE DATE RECORD DATE  \
# 377658   22.0   NaN        NaT  2018-11-12
# 297065   22.0   NaN        NaT  2018-11-12
# 341600   22.0   NaN        NaT  2018-11-12
# 193004   22.0   NaN        NaT  2018-11-12
# 12       12.0     A 2018-03-07  2018-11-12
# 14685    12.0     A 2018-03-07  2018-11-12
# 128658   12.0     A 2018-03-07  2018-11-12
# 74945    31.0   NaN        NaT  2018-11-12
# 65739    31.0   NaN        NaT  2018-11-12
# 255252   31.0   NaN        NaT  2018-11-12
# 270277   31.0   NaN        NaT  2018-11-12
# 283577   31.0   NaN        NaT  2018-11-12
# 326819   31.0   NaN        NaT  2018-11-12
# 327638    NaN   NaN        NaT  2018-11-12
# 176638   12.0     A 2018-10-09  2018-11-12
# 208115   12.0     A 2018-10-09  2018-11-12
# 240330   12.0     A 2018-10-09  2018-11-12
#
#                                           INSPECTION TYPE
# 377658      Pre-permit (Operational) / Initial Inspection
# 297065      Pre-permit (Operational) / Initial Inspection
# 341600      Pre-permit (Operational) / Initial Inspection
# 193004      Pre-permit (Operational) / Initial Inspection
# 12               Pre-permit (Operational) / Re-inspection
# 14685            Pre-permit (Operational) / Re-inspection
# 128658           Pre-permit (Operational) / Re-inspection
# 74945               Cycle Inspection / Initial Inspection
# 65739               Cycle Inspection / Initial Inspection
# 255252              Cycle Inspection / Initial Inspection
# 270277              Cycle Inspection / Initial Inspection
# 283577              Cycle Inspection / Initial Inspection
# 326819              Cycle Inspection / Initial Inspection
# 327638  Administrative Miscellaneous / Initial Inspection
# 176638                   Cycle Inspection / Re-inspection
# 208115                   Cycle Inspection / Re-inspection
# 240330                   Cycle Inspection / Re-inspection

# %%
import import_ipynb
import Scrape
# Out:
# importing Jupyter notebook from Scrape.ipynb
# Scrape.ipynb:14: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 14 of the file Scrape.ipynb. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   "import requests"
# Scrape.ipynb:28: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 28 of the file Scrape.ipynb. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   "cell_type": "code",
# Scrape.ipynb:129: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 129 of the file Scrape.ipynb. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   "                er_friends = review.find('li', {'class': 'friend-count responsive-small-display-inline-block'}).get_text().strip().split(' ')[0].strip()\n",

# %%
import pandas as pd

# %%
df = pd.DataFrame({'a': {"ccc":1, 'dd':2}, 'b':1})

# %%
df
# Out:
#      a  b
# ccc  1  1
# dd   2  1
